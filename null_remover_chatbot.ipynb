# %%
import pandas as pd

# %%
df = pd.read_excel("C:\\Users\\ROG\\Downloads\\bhel_dataset.xlsx")

# %%
df.head()
# Out:
#    COMPLAINT_NO      COMPLAINT_DATE       ID_NO FAULTY_EQUIPMENT  \
# 0        183217 2015-12-30 16:58:57  20151566.0               PC
# 1        183216 2015-12-30 16:54:48  20150737.0          PRINTER
# 2        183215 2015-12-30 16:53:41  20151055.0               PC
# 3        183214 2015-12-30 16:53:20  20150735.0          PRINTER
# 4        183213 2015-12-30 16:51:35  20150329.0               PC
#
#              PROBLEM_TYPE                 PROBLEM_DESCRIPTION  \
# 0          Does not start      pc not lofin trust error  show
# 1  Other - Please Specify                    Printer off line
# 2          Does not start  new pc configration and domain add
# 3  Other - Please Specify                    Printer off line
# 4  Other - Please Specify                  .lst file not open
#
#   NAME_OF_EQUIPMENT EQUIPMENT_MAKE SERVICE_COMPANY  ASSIGN_DATE  \
# 0  HIGHER RAM HP PC            NaN           WIPRO          NaN
# 1            PC GEN            NaN           WIPRO          NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape     #102564 rows and 15 columns
# Out:
# (102564, 15)

# %%
df.columns
# Out:
# Index(['COMPLAINT_NO', 'COMPLAINT_DATE', 'ID_NO', 'FAULTY_EQUIPMENT',
#        'PROBLEM_TYPE', 'PROBLEM_DESCRIPTION', 'NAME_OF_EQUIPMENT',
#        'EQUIPMENT_MAKE', 'SERVICE_COMPANY', 'ASSIGN_DATE', 'RESPONSE_DATE',
#        'RESPONSE_DESCRIPTION', 'SERVICE_DATE', 'REMEDY_DESCRIPTION',
#        'SOLVED_PROBLEM_TYPE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# COMPLAINT_NO                     int64
# COMPLAINT_DATE          datetime64[ns]
# ID_NO                          float64
# FAULTY_EQUIPMENT                object
# PROBLEM_TYPE                    object
# PROBLEM_DESCRIPTION             object
# NAME_OF_EQUIPMENT               object
# EQUIPMENT_MAKE                  object
# SERVICE_COMPANY                 object
# ASSIGN_DATE                    float64
# RESPONSE_DATE           datetime64[ns]
# RESPONSE_DESCRIPTION           float64
# SERVICE_DATE            datetime64[ns]
# REMEDY_DESCRIPTION              object
# SOLVED_PROBLEM_TYPE             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102564 entries, 0 to 102563
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   COMPLAINT_NO          102564 non-null  int64
#  1   COMPLAINT_DATE        102564 non-null  datetime64[ns]
#  2   ID_NO                 100983 non-null  float64
#  3   FAULTY_EQUIPMENT      49628 non-null   object
#  4   PROBLEM_TYPE          49628 non-null   object
#  5   PROBLEM_DESCRIPTION   98903 non-null   object
#  6   NAME_OF_EQUIPMENT     90632 non-null   object
#  7   EQUIPMENT_MAKE        45643 non-null   object
#  8   SERVICE_COMPANY       102560 non-null  object
#  9   ASSIGN_DATE           0 non-null       float64
#  10  RESPONSE_DATE         89917 non-null   datetime64[ns]
#  11  RESPONSE_DESCRIPTION  0 non-null       float64
#  12  SERVICE_DATE          98774 non-null   datetime64[ns]
#  13  REMEDY_DESCRIPTION    98116 non-null   object
# ...

# %%
df.isnull()        #will check every cell if the value is nul or not
# Out:
#         COMPLAINT_NO  COMPLAINT_DATE  ID_NO  FAULTY_EQUIPMENT  PROBLEM_TYPE  \
# 0              False           False  False             False         False
# 1              False           False  False             False         False
# 2              False           False  False             False         False
# 3              False           False  False             False         False
# 4              False           False  False             False         False
# ...              ...             ...    ...               ...           ...
# 102559         False           False  False              True          True
# 102560         False           False  False              True          True
# 102561         False           False  False              True          True
# 102562         False           False  False              True          True
# 102563         False           False  False              True          True
#
# ...

# %%
df.isnull().sum()         #total number of null values in each column
# Out:
# COMPLAINT_NO                 0
# COMPLAINT_DATE               0
# ID_NO                     1581
# FAULTY_EQUIPMENT         52936
# PROBLEM_TYPE             52936
# PROBLEM_DESCRIPTION       3661
# NAME_OF_EQUIPMENT        11932
# EQUIPMENT_MAKE           56921
# SERVICE_COMPANY              4
# ASSIGN_DATE             102564
# RESPONSE_DATE            12647
# RESPONSE_DESCRIPTION    102564
# SERVICE_DATE              3790
# REMEDY_DESCRIPTION        4448
# SOLVED_PROBLEM_TYPE      36825
# dtype: int64

# %%
df2 = df.fillna({'FAULTY_EQUIPMENT':'OTHER',
                'PROBLEM_TYPE':'Other - Please specify',
                'NAME_OF_EQUIPMENT':'OTHERS',
                'EQUIPMENT_MAKE':'OTHERS',
                'SERVICE_COMPANY':'OTHERS'})

# %%
df2
# Out:
#         COMPLAINT_NO      COMPLAINT_DATE       ID_NO FAULTY_EQUIPMENT  \
# 0             183217 2015-12-30 16:58:57  20151566.0               PC
# 1             183216 2015-12-30 16:54:48  20150737.0          PRINTER
# 2             183215 2015-12-30 16:53:41  20151055.0               PC
# 3             183214 2015-12-30 16:53:20  20150735.0          PRINTER
# 4             183213 2015-12-30 16:51:35  20150329.0               PC
# ...              ...                 ...         ...              ...
# 102559         80663 2010-01-01 10:08:34  20060023.0            OTHER
# 102560         80662 2010-01-01 09:56:56  20090000.0            OTHER
# 102561         80661 2010-01-01 09:48:04  20090000.0            OTHER
# 102562         80660 2010-01-01 09:43:31  20090000.0            OTHER
# 102563         80659 2010-01-01 09:35:03  20060811.0            OTHER
#
#                   PROBLEM_TYPE  \
# 0               Does not start
# 1       Other - Please Specify
# ...

# %%
df2.dropna(subset=['ID_NO'], inplace=True)

# %%
print(df2)
# Out:
#         COMPLAINT_NO      COMPLAINT_DATE       ID_NO FAULTY_EQUIPMENT  \
# 0             183217 2015-12-30 16:58:57  20151566.0               PC
# 1             183216 2015-12-30 16:54:48  20150737.0          PRINTER
# 2             183215 2015-12-30 16:53:41  20151055.0               PC
# 3             183214 2015-12-30 16:53:20  20150735.0          PRINTER
# 4             183213 2015-12-30 16:51:35  20150329.0               PC
# ...              ...                 ...         ...              ...
# 102559         80663 2010-01-01 10:08:34  20060023.0            OTHER
# 102560         80662 2010-01-01 09:56:56  20090000.0            OTHER
# 102561         80661 2010-01-01 09:48:04  20090000.0            OTHER
# 102562         80660 2010-01-01 09:43:31  20090000.0            OTHER
# 102563         80659 2010-01-01 09:35:03  20060811.0            OTHER
#
#                   PROBLEM_TYPE  \
# 0               Does not start
# 1       Other - Please Specify
# ...

# %%
df2.dropna(subset=['PROBLEM_DESCRIPTION'], inplace=True)

# %%
df2
# Out:
#         COMPLAINT_NO      COMPLAINT_DATE       ID_NO FAULTY_EQUIPMENT  \
# 0             183217 2015-12-30 16:58:57  20151566.0               PC
# 1             183216 2015-12-30 16:54:48  20150737.0          PRINTER
# 2             183215 2015-12-30 16:53:41  20151055.0               PC
# 3             183214 2015-12-30 16:53:20  20150735.0          PRINTER
# 4             183213 2015-12-30 16:51:35  20150329.0               PC
# ...              ...                 ...         ...              ...
# 102559         80663 2010-01-01 10:08:34  20060023.0            OTHER
# 102560         80662 2010-01-01 09:56:56  20090000.0            OTHER
# 102561         80661 2010-01-01 09:48:04  20090000.0            OTHER
# 102562         80660 2010-01-01 09:43:31  20090000.0            OTHER
# 102563         80659 2010-01-01 09:35:03  20060811.0            OTHER
#
#                   PROBLEM_TYPE  \
# 0               Does not start
# 1       Other - Please Specify
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97322 entries, 0 to 102563
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   COMPLAINT_NO          97322 non-null  int64
#  1   COMPLAINT_DATE        97322 non-null  datetime64[ns]
#  2   ID_NO                 97322 non-null  float64
#  3   FAULTY_EQUIPMENT      97322 non-null  object
#  4   PROBLEM_TYPE          97322 non-null  object
#  5   PROBLEM_DESCRIPTION   97322 non-null  object
#  6   NAME_OF_EQUIPMENT     97322 non-null  object
#  7   EQUIPMENT_MAKE        97322 non-null  object
#  8   SERVICE_COMPANY       97322 non-null  object
#  9   ASSIGN_DATE           0 non-null      float64
#  10  RESPONSE_DATE         86357 non-null  datetime64[ns]
#  11  RESPONSE_DESCRIPTION  0 non-null      float64
#  12  SERVICE_DATE          95248 non-null  datetime64[ns]
#  13  REMEDY_DESCRIPTION    94611 non-null  object
# ...

# %%
df2.dropna(subset=['REMEDY_DESCRIPTION'], inplace=True)

# %%
df2
# Out:
#         COMPLAINT_NO      COMPLAINT_DATE       ID_NO FAULTY_EQUIPMENT  \
# 0             183217 2015-12-30 16:58:57  20151566.0               PC
# 1             183216 2015-12-30 16:54:48  20150737.0          PRINTER
# 2             183215 2015-12-30 16:53:41  20151055.0               PC
# 3             183214 2015-12-30 16:53:20  20150735.0          PRINTER
# 4             183213 2015-12-30 16:51:35  20150329.0               PC
# ...              ...                 ...         ...              ...
# 102559         80663 2010-01-01 10:08:34  20060023.0            OTHER
# 102560         80662 2010-01-01 09:56:56  20090000.0            OTHER
# 102561         80661 2010-01-01 09:48:04  20090000.0            OTHER
# 102562         80660 2010-01-01 09:43:31  20090000.0            OTHER
# 102563         80659 2010-01-01 09:35:03  20060811.0            OTHER
#
#                   PROBLEM_TYPE  \
# 0               Does not start
# 1       Other - Please Specify
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94611 entries, 0 to 102563
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   COMPLAINT_NO          94611 non-null  int64
#  1   COMPLAINT_DATE        94611 non-null  datetime64[ns]
#  2   ID_NO                 94611 non-null  float64
#  3   FAULTY_EQUIPMENT      94611 non-null  object
#  4   PROBLEM_TYPE          94611 non-null  object
#  5   PROBLEM_DESCRIPTION   94611 non-null  object
#  6   NAME_OF_EQUIPMENT     94611 non-null  object
#  7   EQUIPMENT_MAKE        94611 non-null  object
#  8   SERVICE_COMPANY       94611 non-null  object
#  9   ASSIGN_DATE           0 non-null      float64
#  10  RESPONSE_DATE         85633 non-null  datetime64[ns]
#  11  RESPONSE_DESCRIPTION  0 non-null      float64
#  12  SERVICE_DATE          94610 non-null  datetime64[ns]
#  13  REMEDY_DESCRIPTION    94611 non-null  object
# ...
