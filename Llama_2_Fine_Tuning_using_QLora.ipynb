# %% [markdown]
# **Code Credit: Hugging Face**
#
# **Dataset Credit: https://twitter.com/Dorialexander/status/1681671177696161794 **

# %% [markdown]
# ## Finetune Llama-2-7b on a Google colab
#
# Welcome to this Google Colab notebook that shows how to fine-tune the recent Llama-2-7b model on a single Google colab and turn it into a chatbot
#
# We will leverage PEFT library from Hugging Face ecosystem, as well as QLoRA for more memory efficient finetuning

# %% [markdown]
# ## Setup
#
# Run the cells below to setup and install the required libraries. For our experiment we will need `accelerate`, `peft`, `transformers`, `datasets` and TRL to leverage the recent [`SFTTrainer`](https://huggingface.co/docs/trl/main/en/sft_trainer). We will use `bitsandbytes` to [quantize the base model into 4bit](https://huggingface.co/blog/4bit-transformers-bitsandbytes). We will also install `einops` as it is a requirement to load Falcon models.

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 91.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.4 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 23.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %%
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
dp=pd.read_csv('/content/train.csv')

# %%
dp
# Out:
#                                                Questions  \
# 0      Problem in- PC, Problem type is- Does not star...
# 1      Problem in- PRINTER, Problem type is- Other - ...
# 2      Problem in- PC, Problem type is- Does not star...
# 3      Problem in- PRINTER, Problem type is- Other - ...
# 4      Problem in- PC, Problem type is- Other - Pleas...
# ...                                                  ...
# 49995  Problem in- OTHER, Problem type is- Other - Pl...
# 49996  Problem in- PC, Problem type is- Virus, Proble...
# 49997  Problem in- PC, Problem type is- Virus, Proble...
# 49998  Problem in- SCANNER, Problem type is- Other - ...
# 49999  Problem in- OTHER, Problem type is- Other - Pl...
#
#                          Answers  \
# 0         currupt profile reset
# 1                Changed setting
# 2                config properly
# 3                 Resolved issue
# 4               Changed setting
# ...                          ...
# 49995  Call transferred - 128205
# 49996  Call transferred - 128202
# 49997  Call transferred - 128184
# 49998      scanner settings done
# 49999                 NETWORK OK
#
#                                                     text
# 0      you are given details on an issue faced by our...
# 1      you are given details on an issue faced by our...
# 2      you are given details on an issue faced by our...
# 3      you are given details on an issue faced by our...
# 4      you are given details on an issue faced by our...
# ...                                                  ...
# 49995  you are given details on an issue faced by our...
# 49996  you are given details on an issue faced by our...
# 49997  you are given details on an issue faced by our...
# 49998  you are given details on an issue faced by our...
# 49999  you are given details on an issue faced by our...
#
# [50000 rows x 3 columns]

# %% [markdown]
# ## Loading the model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "TinyPixel/Llama-2-7B-bf16-sharded"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00014.bin:   0%|          | 0.00/981M [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00008-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00009-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00010-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00011-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00012-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00013-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00014-of-00014.bin:   0%|          | 0.00/847M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
from peft import LoraConfig, get_peft_model

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM"
)

# %% [markdown]
# ## Loading the trainer

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 100
logging_steps = 10
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 100
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Then finally pass everthing to the trainer

# %%
from datasets import DatasetDict, Dataset
dset = {
    "Human": dp["Questions"],
    "Assistent": dp["Answers"]
}
dataset = Dataset.from_dict(dset)

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="Human",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:207: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %% [markdown]
# We will also pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Now let's train the model! Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/content/wandb/run-20230829_073233-4ko8gd98</code>
# Syncing run <strong><a href='https://wandb.ai/devis2/huggingface/runs/4ko8gd98' target="_blank">gentle-sunset-2</a></strong> to <a href='https://wandb.ai/devis2/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/devis2/huggingface' target="_blank">https://wandb.ai/devis2/huggingface</a>
#  View run at <a href='https://wandb.ai/devis2/huggingface/runs/4ko8gd98' target="_blank">https://wandb.ai/devis2/huggingface/runs/4ko8gd98</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 10:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.887600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.423400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.982900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.087800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.745500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.971600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.215300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.003100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.911100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.875100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=1.7103435611724853, metrics={'train_runtime': 712.9108, 'train_samples_per_second': 2.244, 'train_steps_per_second': 0.14, 'total_flos': 1568544198819840.0, 'train_loss': 1.7103435611724853, 'epoch': 0.03})

# %% [markdown]
# During training, the model should converge nicely as follows:
#
# ![image](https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/loss-falcon-7b.png)
#
# The `SFTTrainer` also takes care of properly saving only the adapters during training instead of saving the entire model.

# %%
model_to_save = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model  # Take care of distributed/parallel training
model_to_save.save_pretrained("outputs")

# %%
lora_config = LoraConfig.from_pretrained('outputs')
model = get_peft_model(model, lora_config)

# %%
dataset['Human']
# Out:
# ['Problem in- PC, Problem type is- Does not start, Problem description is- pc not lofin trust error  show, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- Printer off line, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- new pc configration and domain add, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- Printer off line, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- .lst file not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Intranet is not working. , Name of Equipment- pc, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- network not available., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- excel not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pdf software not installed, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- Attendance Sys  & HR  not login, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- share folder of this pc not allowed to acces from 10.4.144.1, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- NEW PRINTER IS TO BE INSTALLED, Name of Equipment- LJ (A3), Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Bin detail do not downloading, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Hindi fonts for Autocad to be installed., Name of Equipment- PC-ENGINEERING, Service Company is- AUTOCAD',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- paper jam, Name of Equipment- DMP-5235, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Intranet is not working. , Name of Equipment- pc, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- FOR NET CABLE EXTEND , Name of Equipment- FOR NET CABLE EXTEND, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Hindi fonts for Autocad to be installed., Name of Equipment- PC-ENGINEERING, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PC does not start with password, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- install 32 bit MS office and remove 64 bit MS office, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Hindi fonts for Autocad to be installed., Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- network not available., Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- network not available., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- system become lock --not open---urgent----, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network is not coming, Name of Equipment- lenovo, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- No sound. Please look into., Name of Equipment- PC-GEN, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- connect to lan,and network,connect printer etc, Name of Equipment- lennovo, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- NETWORK NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- NETWORK NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is-   Intranet is not working.  , Name of Equipment- pc, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- COMP.NO.183145  NOT RESOLVED, Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- network not working , Name of Equipment- pc, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer offilne, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- MONITOR, Problem type is- Other - Please Specify, Problem description is- MONITOR HAS A MARK, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- New connection, Problem description is- network not working, Name of Equipment- PC-ENGINEERING, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- hindi font for autocad reqired, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- New connection, Problem description is- network not working, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- COMP.NO.183145  NOT RESOLVED, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Installation of MS ACCESS in my PC., Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- Password expired, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK NOT WORKING, Name of Equipment- LENOVO, Service Company is- NETWORK',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- NEW PRINTER  ISSUED  TO BE INSTALLED, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- INTRANET NOT WORKING, Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Need a port for printer, Name of Equipment- Network Port, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- UNABLE TO LOGIN TO COMPUTER, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- for attachment of printer., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- P C not working properly., Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- os upgadation win 8 to win 10, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- os upgradation win 8 to win 10, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- os upgradtion win 8 to win 10, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- usb and cddrive need to block, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- usb need to block and CdDrive not readable, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- need to upgrade windows 10, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- win 10 installed, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc update to win 8 to Win 10, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- PRINTER NOT WORKING 1566, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NO NETWORK, Name of Equipment- COMPUTER, Service Company is- NETWORK',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- Printer Not Working, Name of Equipment- LJ-A4-MONO 1566, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- Oracle applications not running properly, problem in generat, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- INTRANET NOT WORKING, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- PC DOES NOT START, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- SCANNER, Problem type is- Other - Please specify, Problem description is- VERY SLOW NOT WORKING MANYTIME PLS REPLACE WITH NEW SCANNER, Name of Equipment- SCANNER A3 PRO, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- front page required, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- NO NETWORK, Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- NO NETWORK, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- wipro dot matrix printer not working, Name of Equipment- DMP-5235, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- printer not connected driver not found, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- printer not proper work(device not proper work), Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NO INTERNET ACCESS ICON SHOWS AT LEFT BOTTOM OF PC, Name of Equipment- PC LENOVO, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- configure outlook, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- NET WORK NOT WORKING, Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PDF files not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- PDF File reader is corrupted, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Intranet not access, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- NET WORK NOT WORKING, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Emp attendance portal and ESS and internet not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network issues as printer showing offline, Name of Equipment- Printer, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network issues as printer showing offline, Name of Equipment- Printer, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network issues as printer showing offline, Name of Equipment- Printer, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORKING PROBLEM, Name of Equipment- PC LENOVO, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- PC NOT SHARED, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- wrench donot open, Name of Equipment- DMP-5235, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- wrench software required to be load, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER NOT WORK, Name of Equipment- 20150562, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- Printer showing offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network issues as printer showing offline, Name of Equipment- Printer, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc beeping contineously, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER NOT WORK, Name of Equipment- 20150562, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- New PC add in Domain and Softwares Installation, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- IP PROBLEM , Name of Equipment- PC , Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- I P  problem, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- LOGIN PROBLEM, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- free sites not working, please update brawser in my pc, Name of Equipment- PC-GEN, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc configuration, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- winzip not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer not connect, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- computer not work, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- MOUSE, Problem type is- Not working, Problem description is- Mouse is not working properly., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK PROBLEM, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK PROBLEM, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- UPS, Problem type is- Other - Please Specify, Problem description is- UPS OF HUB TO BE CHANGED, CREATING PROBLEM, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK PROBLEM, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK PROBLEM, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- outlook not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Printer is not working with new HP computer (they are not sy, Name of Equipment- Printer no 20/11323, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- need to share drive, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- paper is getting strucked in printer., Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Printer is not working with new HP computer (they are not sy, Name of Equipment- Printer no 20/11323, Service Company is- NETWORK',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- printer not working, Name of Equipment- LJ-A4-MONO 2055, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- web printer not work, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Domain problem, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- required install image composer 1.5, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- bhel intranet not working, Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- bhel intranet not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- No connectivity at Gate Number 4., Name of Equipment- Smart Card Reader, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- SCANER CANECT, Name of Equipment- UPS, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- pl. install autocad, Name of Equipment- PC GEN, Service Company is- AUTOCAD',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- no network, Name of Equipment- pc, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- pl. install autocad, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- winzip software installation, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- PCnot working.Please solve., Name of Equipment- PC-GEN, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Intranet is not working., Name of Equipment- Network, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- please install autocad and unigraphic software, Name of Equipment- PC GEN, Service Company is- AUTOCAD',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- please install autocad and unigraphic software, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- 2 NOS 4 MTRS LAN CABLE REQUIRED., Name of Equipment- LENOVO, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Working slow, Problem description is- PC PEROBLAM, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK PROBLEM, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- pls reinstall  adobe acrobat latest version, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK  NOT AVAILABLE, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- SCANER CANECT, Name of Equipment- UPS, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Pls. install google chrome, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PDF FILES ARE NOT OPENING, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- intranet not working, Name of Equipment- PC-GEN, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- upgrade the internet brower  in this pc., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PC NOT CONNECTING TO THE NETWORK, Name of Equipment- 20122189, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- window error, Name of Equipment- ITON-UP, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- ms outlook & NX s/w not open, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- web printer not work, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- ess not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- word not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- system not start, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Working slow, Problem description is- PC AND NET, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- softwares installation with doamin process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- config required with softwares, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- domain add with softwares, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc config with software, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- PRINTER NOT WORKING, Name of Equipment- LJ-A3-MONO 9040, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- pc config domain add, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- domain procces with soft installation, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PC configure and AD process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc config and domain add, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- mails are getting recieved very late more than 5 minutes, Name of Equipment- network, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- intranet not working, Name of Equipment- PC-GEN, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Internet not working, Name of Equipment- internet, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Please install google chrome., Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Net work connection pont not working, Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Please install   FTP Server  for windows 8., Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PC configure and AD process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PC configure and AD process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- digital signature is not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- e token driver re-instalation require, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- mails are getting recieved very late more than 5 minutes, Name of Equipment- network, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Net work connection pont not working, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- camera installation, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- paper is getting strucked in printer., Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- PC is not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- printer head running wire sparking then stop,, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer not working, Name of Equipment- printer, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer not working, Name of Equipment- printer , Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- UNABLE TO LOGIN, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- password expire, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- Refrence A/C Closed, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PC KEEPS GETTING DISCONNECTED FROM NETWORK, Name of Equipment- NETWORK, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PC configure and AD process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- PC configure and AD process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- INSTALLATION OF PRINTER, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- network not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRANET IS NOT WORKING CONDITION, Name of Equipment- HP, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Dous not  print Plotter, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NET IS NOT AVAILABLE, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- UNABLE TO BOOK NTPC CALL, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- Install express tool in autocad, Name of Equipment- PC-ENGINEERING, Service Company is- AUTOCAD',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- Install express tool in autocad, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK NOT WORKING., Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Intranet is not working repeted problem again., Name of Equipment- INTRANET, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- add network printer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer problem, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- ms office not activated, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- excel site corrupted file, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- internet not working, Name of Equipment- PC-ENGINEERING, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRANET IS NOT WORKING CONDITION, Name of Equipment- HP, Service Company is- NETWORK',
#  'Problem in- MOUSE, Problem type is- Not working, Problem description is- scroll button is not working, (urgent), Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer need to shared, Name of Equipment- UPS- UNILINE, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Please install MS PROJECT software., Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Please install MS PROJECT software., Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network not working, Name of Equipment- Computer, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pdf files not print, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- hp 1566 printer installation, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRANET IS NOT WORKING CONDITION, Name of Equipment- HP, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- pdf not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- new printer to be installed, Name of Equipment- LJ-A4-MONO 1566, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRANET CONNECTION PROBLEM, Name of Equipment- LENOVO, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Intranet is not working repeted problem again., Name of Equipment- INTRANET, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- OUTLOOK CONFIGURATION REQUIRED, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- pc problem not start, Name of Equipment- 2524376, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRANET IS NOT WORKING CONDITION, Name of Equipment- HP, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- web printer offline again to again, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- REPLACE PC  LENOVO, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- add network printer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- UPS, Problem type is- Other - Please Specify, Problem description is- swich off autmetically, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- p c set, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRANET IS NOT WORKING CONDITION, Name of Equipment- HP, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer installation, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- plz install new printer, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- Acrobat files not opening, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- internet not working, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- pc problem not start, Name of Equipment-   2524376, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- unidentifid  internet , Name of Equipment- hp, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Net work not comming properly, Name of Equipment- P C, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Intranet not working., Name of Equipment- Internet Problem, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- pdf attachment with email not responding, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- NTPC Call Booking not possible with current operating system, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- Antivirus installation required, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- MONITOR, Problem type is- Monitor Flickering, Problem description is- it start flikering suddenly.repeating many times  a day., Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- UPS, Problem type is- No backup, Problem description is- UPS NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Net work not comming properly, Name of Equipment- P C, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- unidentifid  internet , Name of Equipment- hp, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- NOT WORKING, Name of Equipment- LJ-A4-MONO 2055, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Net work not comming properly, Name of Equipment- P C , Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- Printer shows offline, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- out of domain  checked by network service person, Name of Equipment- PC-GEN, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- Add printer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer to be added in computer, Name of Equipment- printer to be installed, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- install indic hindi enable, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- printer not working properly, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- FORGOT PASSWORD. NOT ABLE TO START, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- xml file not save, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Printer not added, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- Add printer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer to be added in computer, Name of Equipment- printer to be installed, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- unidentifid  internet , Name of Equipment- hp, Service Company is- NETWORK',
#  'Problem in- MONITOR, Problem type is- Monitor Flickering, Problem description is- SCREEN IS VIBRATING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- print quality is not readable, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- attendance sheet not print, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTERNET/INTRANET NOT WORKING, Name of Equipment- NETWORK, Service Company is- NETWORK',
#  'Problem in- KEYBOARD, Problem type is- Specific key not working, Problem description is- Zero key of numeric panel is not functioning, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTERNET CONNECTION NOT WORKING, Name of Equipment- HP, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- unable to open zip files, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- CONNECTING PRINTER, Name of Equipment- PC, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- PRINT OF THE M.S. WORD NOT PROPER., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- free sites not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- PRINTOF THE M.S.WORD NOT PROPER., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- network problem, Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- system hang, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- dotmatric printer offline, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer offline showing, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- please install printer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer not start, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- CONNECTING PRINTER, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- UPS, Problem type is- Other - Please Specify, Problem description is- HEAT-UP & BURNING SMELL, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- net work not come properly, Name of Equipment- pc, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc slow working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- network problem, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc not open, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- UPS NOT WORKING, Name of Equipment- UPS, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- UPS NOT WORKING, Name of Equipment- UPS, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER IS NOT WORKING., Name of Equipment- MATRIX PRINTER, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER IS NOT WORKING., Name of Equipment- PRINTER, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- attendance system not login, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER IS NOT WORKING., Name of Equipment- MATRIX PRINTER, Service Company is- NETWORK',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
# ...
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTRNET NOT WORKING, Name of Equipment- PC , Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- INTRANET NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- adobe need to update, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- INTRANET NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- NETWORK NOT WORKING IN MACHINE SHOP PC ONLY, Name of Equipment- PC-GENERAL, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- NETWORK NOT WORKING IN MACHINE SHOP PC ONLY, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- INTERNET NOT WORKING ONLY IN MACHINE SHOP PC, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- please install acrobat reader, Name of Equipment- HIGHER RAM HP PC, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- printer not getting installed, Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- adobe files not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer offline showing, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- DOES NOT LOGIN., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NO NETWORK, Name of Equipment- NO NETWORK, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is-  PROPER ROTING OF LAN WIRES , Name of Equipment- LAN WIRE, Service Company is- NETWORK',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- printer not getting installed, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- MOUSE, Problem type is- Not working, Problem description is- not working proper, getting double click on single click., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- MOUSE, Problem type is- Not working, Problem description is- not working proper, getting double click on single click., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- plz install printer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- DOT MATRIX PRINTER IS NOT WORKING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer offline, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- UPS, Problem type is- No backup, Problem description is- COM NO. 181188 BATTERY WAS  NOT REPLACED AND COMPLAIN CLOSED, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- PC NOT START, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Re-install Internet Explorer, Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- Printer software, Outlook,Favorites and Z Drive, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER NOT CONNECTING, Name of Equipment- PRINTER, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- CHANGE IP ADDRESS, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- UPS, Problem type is- No backup, Problem description is- No Backup, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- UPS, Problem type is- No backup, Problem description is- No Backup, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER NOT CONNECTING, Name of Equipment- PRINTER, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- DATA BACKUP, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc configuration and AD process, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- pc config with Data backup, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- USB PRINTER OFF LINE, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- CHANGE IP ADDRESS, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network Cable to be extended, Name of Equipment- Desktop, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- Please load the Oracle developer suite 11g on this PC., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Other - Please Specify, Problem description is- CHANGE IP ADDRESS, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Data backup, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- plesae install Auto-cad  (  auto  no.2748), Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Paper gets stuck, Problem description is- Printer not proper work., Name of Equipment- DMP-5235, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- network not work, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pc not login incorrect password error, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- plz install hindi indic tool, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER CORRECTLY NOT WORKING, Name of Equipment- PRINTER, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PRINTER CORRECTLY NOT WORKING, Name of Equipment- PRINTER , Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- UPS IS NOT WORKING , Name of Equipment- PC, Service Company is- HCL',
#  'Problem in- PLOTTER, Problem type is- Not working, Problem description is- print head jam plotter not working, Name of Equipment- PLOTTER, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- Old pc data transfer, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- New PC software installation, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- printer attach, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Autocad not working properly, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- PRINTER ATTACH, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- UPS IS NOT WORKING , Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Software installation, Problem description is- PLEASE INSTALL MANGAL FONT, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- plz install sqldeveloper, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- SHIFT INTERNANET CONNECTION  (LENOVO), Name of Equipment- PC, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK PORT NOT WORKING., Name of Equipment- NETWORK PORT, Service Company is- NETWORK',
#  'Problem in- UPS, Problem type is- No backup, Problem description is- not a single second backup., Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Install e token driver, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Paper gets stuck, Problem description is- DOTMATRIX PRINTER NOT WORKING.URGENT REQD., Name of Equipment- DMP-5235, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NET WORK PROBLEM, Name of Equipment- NETWORK, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NET WORK PROBLEM, Name of Equipment- NETWORK, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK NOT WORKING., Name of Equipment- HP, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NET WORK PROBLEM, Name of Equipment- NETWORK, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PLEASE CONNECT MY PC  WITH MY PRINTER, Name of Equipment- PRINTER, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- action pending on complaint no. 181704 &182014  ., Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer is not working (urgentaly), Name of Equipment- pfr printer, Service Company is- HCL',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- JAVA BASED APPLICATION ARE NOT RUNNING, Name of Equipment- PC-GENERAL, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- NETWORK NOT WORKING., Name of Equipment- HP, Service Company is- HCL',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- Network cable problem., Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- plz change passwd, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Other - Please specify, Problem description is- Network cable problem., Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- NETWORK, Problem type is- Existing network not working, Problem description is- INTERNET NOT WORKING, Name of Equipment- PC GEN, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- free sites not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- NETWORK PRINTER PROBLEM, Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- printer is not working (urgentaly), Name of Equipment- pfr printer, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- action pending on complaint no. 181704 &182014  ., Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- pdf not open, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- network not coming, Name of Equipment- lenovo, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Plz install printer id address 10.4.143.24, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- internet not working with free sites, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- plz install pdf acrobate latest, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- intranet not opening, Name of Equipment- PC-ENGINEERING, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- intranet not opening, Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Unable to open online work order link ., Name of Equipment- PC-ENGINEERING, Service Company is- HCL',
#  'Problem in- PRINTER, Problem type is- Paper gets stuck, Problem description is- URGENT REQUIRED., Name of Equipment- DMP-5235, Service Company is- HCL',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Network not coming, Name of Equipment- 20150800, Service Company is- NETWORK',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- PLEASE CONNECT MY PC  WITH MY PRINTER, Name of Equipment- PRINTER, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Other - Please Specify, Problem description is- Internet Explorer cannot display the web page., Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- printer not working, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- network problem, Name of Equipment- printer, Service Company is- NETWORK',
#  'Problem in- PC, Problem type is- Does not start, Problem description is- computer not login, Name of Equipment- PC GEN, Service Company is- WIPRO',
#  'Problem in- PRINTER, Problem type is- Not working, Problem description is- action pending on complaint no. 181704 &182014  ., Name of Equipment- LJ PRINTER A4 MONO GEN-401 DNE, Service Company is- WIPRO',
#  ...]

# %%
text = "Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Printer is not working with new HP computer (they are not sy, Name of Equipment- Printer no 20/11323, Service Company is- NETWORK ### Assistant: Call transferred - 183109"
device = "cuda:0"

inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Problem in- OTHER, Problem type is- Other - Please specify, Problem description is- Printer is not working with new HP computer (they are not sy, Name of Equipment- Printer no 20/11323, Service Company is- NETWORK ### Assistant: Call transferred - 18310900000000000000000000000000000000000000000000000000

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub("llama2-qlora-finetunined-query-resolver")
# Out:
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Devis2awe/llama2-qlora-finetunined-query-resolver/commit/f49659482866e77d70f63340a98a1107fbf6220f', commit_message='Upload model', commit_description='', oid='f49659482866e77d70f63340a98a1107fbf6220f', pr_url=None, pr_revision=None, pr_num=None)

# %%
text = "Problem in- PC, Problem type is- Does not start, Problem description is- PC does not start, Name of Equipment- PC GEN, Service Company is- NETWORK"
device = "cuda:0"

inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# Problem in- PC, Problem type is- Does not start, Problem description is- PC does not start, Name of Equipment- PC GEN, Service Company is- NETWORK, Service Type is- Onsite, Service Location is- Home, Service Date is- 12/12/2018, Service Time is- 10:00 AM, Service Duration is- 1 H
